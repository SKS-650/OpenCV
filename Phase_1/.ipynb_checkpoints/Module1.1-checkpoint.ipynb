# %% [markdown]
# # 📘 Module 1.1 – OpenCV Setup + First Programs

# %% [markdown]
# ## ✅ STEP 1: Install OpenCV (One-time)

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\shyam\appdata\roaming\python\python313\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\shyam\appdata\roaming\python\python313\site-packages (from opencv-python) (2.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### ✅ STEP 2: Verify Installation (Example 1)

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.11.0

# %% [markdown]
# ### ✅ STEP 3: Read & Display Image (Example 2 – MUST RUN)

# %%
import cv2

img = cv2.imread("image.jpg")   # put any image in same folder
cv2.imshow("My First Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### ✅ STEP 5: Save Image (Example 3)

# %%
cv2.imwrite("saved_image.png", img)

# %% [markdown]
# ### ✅ STEP 6: Image Properties (Example 4 – VERY IMPORTANT)

# %%
print(img.shape)    # (height, width, channels)
print(img.dtype)    # usually uint8
# Out:
# (2000, 3008, 3)
# uint8

# %% [markdown]
# ### ✅ STEP 7: Access Pixel Values (Example 5)

# %%
pixel = img[100, 200]
print(pixel)            # [B G R]
# Out:
# [ 5 13  6]

# %% [markdown]
# ### ✅ STEP 8: Modify Pixel (Example 6)

# %%
img[100, 200] = [0, 0, 255]  # pure RED
cv2.imshow("Pixel Modified", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### ✅ STEP 10: Region of Interest (ROI) – Crop (Example 8)

# %%
roi = img[1400:1600, 900:1100]    #img[row_start : row_end, column_start : column_end]
cv2.imshow("ROI", roi)
cv2.imshow("Pixel Modified", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # END
