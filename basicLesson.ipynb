# %%
import cv2
print(cv2.__version__)
# Out:
# 4.13.0

# %% [markdown]
# # 🟦 3. Reading and Displaying an Image

# %%
import cv2

img = cv2.imread("C:/Users/Shyam/OneDrive/Pictures/sks/test.jpg")  # Put any image inside your folder
cv2.imshow("My First Image", img)
cv2.waitKey(0)      # Wait until a key is pressed
cv2.destroyAllWindows()

# %% [markdown]
# # 🟦 4. Resize Image

# %%
resized = cv2.resize(img, (400, 400))
cv2.imshow("Resized", resized)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 🟦 5. Reading a Video File

# %%
import cv2

cap = cv2.VideoCapture("C:/Users/Shyam/OneDrive/Desktop/Online Shopping App - Final/video.mp4")  # Put any video inside your folder

while True:
    ret, frame = cap.read()     # read one frame
    if not ret:
        break                   # end of video

    cv2.imshow("This is the Ecommerce App Video", frame)

    if cv2.waitKey(20) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Display Only First Frame of Video

# %%
import cv2

cap = cv2.VideoCapture("C:/Users/Shyam/OneDrive/Desktop/Online Shopping App - Final/video.mp4")  # Put any video inside your folder
ret, frame = cap.read()

cv2.imshow("First Frame", frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 🟦 7. Reading Webcam / External Camera
# 🎥 Webcam:
#
# Camera index:
#
# 0 → default webcam
#
# 1 → external camera

# %%
import cv2

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    cv2.imshow("Webcam Live", frame)

    if cv2.waitKey(25) & 0xFF == ord('q'):  
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 🟦 9. Saving (Writing) Video

# %%
import cv2

cap = cv2.VideoCapture(0)

fourcc = cv2.VideoWriter_fourcc(*"XVID")
out = cv2.VideoWriter("C:/Users/Shyam/Videos/bhoj/output.avi", fourcc, 30.0, (640, 480))

while True:
    ret, frame = cap.read()
    out.write(frame)             # save the frame

    cv2.imshow("Recording", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 🟦 8. Saving (Writing) Images
# # 🟦 10. Convert BGR → RGB (Important)

# %%
import cv2

img = cv2.imread("C:/Users/Shyam/Videos/bhoj/test.jpg")  # Put any image inside your folder
# cv2.imshow("My First Image", img)
# cv2.imwrite("C:/Users/Shyam/Videos/bhoj/saved_image.jpg", img)
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imwrite("C:/Users/Shyam/Videos/bhoj/saved_image2.jpg", rgb)
cv2.imshow("RGB", rgb)

hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
cv2.imshow("HSV Image", hsv)
cv2.imshow("Image", img)

cv2.waitKey(0)      # Wait until a key is pressed
cv2.destroyAllWindows()

# %% [markdown]
# # 🟦 1. Resize an Image

# %%
import cv2

img = cv2.imread("C:/Users/Shyam/OneDrive/Pictures/sks/test.jpg")  # Put any image inside your folder
resized = cv2.resize(img, (700, 600))  # width=500, height=300

cv2.imshow("Original", img)
cv2.imshow("Resized", resized)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 🟦 2. Crop an Image

# %%
crop = img[500:2000, 800:1800]   # 1500*1000 (height and width)
cv2.imshow("Cropped", crop)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 🟦 3. Convert Image to Grayscale

# %%
img = cv2.imread("C:/Users/Shyam/OneDrive/Pictures/sks/test.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray Image", gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 🟦 4. Rotate an Image

# %%
img = cv2.imread("C:/Users/Shyam/OneDrive/Pictures/sks/test.jpg")
recize = cv2.resize(img, (800,800))
rotated = cv2.rotate(recize, cv2.ROTATE_90_CLOCKWISE)
#cv2.imshow("Rotated", rotated)
cv2.imshow("Rotated", recize)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
(h, w) = recize.shape[:2]
center = (w//2, h//2)

matrix = cv2.getRotationMatrix2D(center, 180, 1.0)
rotated = cv2.warpAffine(img, matrix, (w, h))

cv2.imshow("Rotated 45 Degrees", rotated)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
flip1 = cv2.flip(img, 1)
line = cv2.line(img.copy(), (50, 50), (300, 50), (255, 0, 0), 3)

# %% [markdown]
# # 🟦 2. Simple Averaging (Blur)

# %%
import cv2

img = cv2.imread("test.jpg")  # Put any image inside your folder

# Kernel size (5,5)
blur = cv2.blur(img, (5, 5))

cv2.imshow("Original", img)
cv2.imshow("Blurred", blur)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gauss = cv2.GaussianBlur(img, (5, 5), 0)
cv2.imshow("Gaussian Blur", gauss)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
median = cv2.medianBlur(img, 5)
cv2.imshow("Median Blur", median)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Bilateral Filter

# %%
bilateral = cv2.bilateralFilter(img, 9, 75, 75)
cv2.imshow("Bilateral Filter", bilateral)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Sharpening an Image

# %%
import numpy as np

kernel = np.array([[0, -1, 0],
                   [-1, 5, -1],
                   [0, -1, 0]])

sharpened = cv2.filter2D(img, -1, kernel)
cv2.imshow("Sharpened", sharpened)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Canny Edge Detection

# %%
import cv2

img = cv2.imread("test.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.imshow("Gray", gray)
cv2.waitKey(0)
# Out:
# -1

# %%
edges = cv2.Canny(gray, 100, 200)  # thresholds

cv2.imshow("Edges", edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=3)  # X gradient
sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=3)  # Y gradient

cv2.imshow("Sobel X", sobelx)
cv2.imshow("Sobel Y", sobely)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Create a Kernel and Erosion and Dilation

# %%
import cv2
import numpy as np

kernel = np.ones((5,5), np.uint8)

# %%
img = cv2.imread("test.jpg", 0)  # grayscale or binary

erosion = cv2.erode(img, kernel, iterations=1)
cv2.imshow("Erosion", erosion)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
dilation = cv2.dilate(img, kernel, iterations=1)
cv2.imshow("Dilation", dilation)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Color Detection Using Masks

# %%
import numpy as np
img = cv2.imread("test.jpg")  # Put any image inside your folder
# Convert to HSV
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Define color range (Blue)
lower_blue = np.array([100, 150, 0])
upper_blue = np.array([140, 255, 255])

# Create mask
mask = cv2.inRange(hsv, lower_blue, upper_blue)

# Apply mask to original image
result = cv2.bitwise_and(img, img, mask=mask)

cv2.imshow("Original", img)
cv2.imshow("Mask", mask)
cv2.imshow("Result", result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #  Track Multiple Colors

# %%
# Example: Red color
lower_red = np.array([0, 120, 70])
upper_red = np.array([10, 255, 255])
mask1 = cv2.inRange(hsv, lower_red, upper_red)

lower_red2 = np.array([170, 120, 70])
upper_red2 = np.array([180, 255, 255])
mask2 = cv2.inRange(hsv, lower_red2, upper_red2)

mask_red = mask1 + mask2
red_result = cv2.bitwise_and(img, img, mask=mask_red)

cv2.imshow("Red Color Detection", red_result)
cv2.imshow("Original", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Lesson 9 — Contours (Shape Detection & Object Boundaries)

# %%
import cv2

img = cv2.imread("test.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.imshow("Original", img)
cv2.imshow("Gray", gray)


# Thresholding
ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
cv2.imshow("Threshold", thresh)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

print(f"Number of contours: {len(contours)}")
# Out:
# Number of contours: 2676

# %%
img_contours = img.copy()
cv2.drawContours(img_contours, contours, -1, (222, 250, 55), 3)  # -1 = draw all

cv2.imshow("Contours", img_contours)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
for cnt in contours:
    x, y, w, h = cv2.boundingRect(cnt)
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

cv2.imshow("Bounding Boxes", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
for cnt in contours:
    (x, y), radius = cv2.minEnclosingCircle(cnt)
    center = (int(x), int(y))
    radius = int(radius)
    cv2.circle(img, center, radius, (0, 255, 255), 2)

cv2.imshow("Circles", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
for cnt in contours:
    area = cv2.contourArea(cnt)
    perimeter = cv2.arcLength(cnt, True)
    print(f"Area: {area}, Perimeter: {perimeter}")
# Out:
# Area: 0.0, Perimeter: 0.0
# Area: 0.0, Perimeter: 0.0
# Area: 0.0, Perimeter: 0.0
# Area: 0.0, Perimeter: 2.8284270763397217
# Area: 0.0, Perimeter: 2.8284270763397217
# Area: 0.0, Perimeter: 4.0
# Area: 0.5, Perimeter: 8.242640614509583
# Area: 0.5, Perimeter: 3.414213538169861
# Area: 0.0, Perimeter: 0.0
# Area: 0.0, Perimeter: 6.0
# Area: 0.0, Perimeter: 0.0
# Area: 1.0, Perimeter: 8.828427076339722
# Area: 0.0, Perimeter: 8.0
# Area: 0.0, Perimeter: 2.0
# Area: 0.0, Perimeter: 8.0
# Area: 0.0, Perimeter: 8.828427076339722
# Area: 0.0, Perimeter: 2.0
# Area: 0.0, Perimeter: 0.0
# Area: 0.0, Perimeter: 8.828427076339722
# Area: 0.5, Perimeter: 6.2426406145095825
# Area: 1.5, Perimeter: 18.242640614509583
# Area: 0.5, Perimeter: 3.414213538169861
# Area: 0.0, Perimeter: 4.828427076339722
# Area: 0.0, Perimeter: 16.485281229019165
# Area: 1.5, Perimeter: 21.071067690849304
# Area: 1.5, Perimeter: 18.242640614509583
# Area: 0.0, Perimeter: 4.828427076339722
# ...

# %% [markdown]
# # Lesson 10 — Image Histograms

# %%
import cv2
from matplotlib import pyplot as plt

img = cv2.imread("C:/Users/Shyam/Videos/bhoj/test.jpg", 0)  # 0 → grayscale

hist = cv2.calcHist([img], [0], None, [256], [0, 256])

plt.plot(hist)
plt.title("Grayscale Histogram")
plt.show()

# %%
img = cv2.imread("C:/Users/Shyam/Videos/bhoj/test.jpg")

colors = ('b','g','r')
for i, col in enumerate(colors):
    hist = cv2.calcHist([img], [i], None, [256], [0,256])
    plt.plot(hist, color=col)
    plt.xlim([0,256])

plt.title("Color Histogram")
plt.show()

# %%
img = cv2.imread("test.jpg", 0)  # grayscale

equ = cv2.equalizeHist(img)

cv2.imshow("Original", img)
cv2.imshow("Equalized", equ)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(img)

cv2.imshow("CLAHE", cl1)
cv2.waitKey(0)
cv2.destroyAllWindows()
